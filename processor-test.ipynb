# %%
from processing_images.processing import combination, transformation
from processing_images.utils import io, plot

# %%
img1 = io.img_read("Assets/bed-1839564_1280.jpg")
img2 = io.img_read("Assets/colour-3286027_1280.jpg")

# %%
plot.img_plot(img1)
plot.img_plot(img2)

# %%
merged_img = combination.histogram_transfer(img1, img2)
plot.img_plot(merged_img)
